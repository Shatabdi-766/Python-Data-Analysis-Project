# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('e:\\Titanic Data Analysis\\train.csv')
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot(x='Sex',data=df,orient='v')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Distribution of Sex');

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# **** Which Gender Survived Most? ****

# %%
sns.countplot(x='Sex',data=df,hue='Survived',orient='v');

# %%
pd.crosstab(df.Sex,df.Survived)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
sns.countplot(x='Pclass',data=df,orient='v')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass',data=df,hue='Sex',orient='v');

# %%
pd.crosstab(df.Sex,df.Pclass)
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %% [markdown]
# **** Which Class Passenger Survived Most ? ****

# %%
sns.countplot(x='Pclass',data=df,hue='Survived',orient='v');

# %%
pd.crosstab(df.Survived,df.Pclass)
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %% [markdown]
# *** Who Survived Most ? ***

# %%
sns.countplot(x='SibSp',data=df,orient='v')
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
sns.countplot(x='Parch',data=df,orient='v')
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
sns.countplot(x='SibSp',data=df,hue='Survived',orient='v');

# %%
pd.crosstab(df.SibSp,df.Survived)
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
sns.lmplot(x='Age',y='Survived',hue='Pclass',data=df);

# %%
sns.countplot(x='Embarked',data=df,orient='v');

# %%
sns.countplot(x='Embarked',data=df,hue='Sex',orient='v')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
pd.crosstab(df.Embarked,df.Sex)
# Out:
# Sex       female  male
# Embarked
# C             73    95
# Q             36    41
# S            203   441

# %%
sns.countplot(x='Embarked',data=df,hue='Survived',orient='v')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
pd.crosstab(df.Embarked,df.Survived)
# Out:
# Survived    0    1
# Embarked
# C          75   93
# Q          47   30
# S         427  217
