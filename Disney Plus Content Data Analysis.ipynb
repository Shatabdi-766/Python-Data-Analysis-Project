# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mlp
import seaborn as sns

# %%
# matplotlib default store
inline_rc = dict(mlp.rcParams)

# %%
# remove warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# come back default value
mlp.rc_file_defaults()
mlp.rcParams.update(inline_rc)

# %%
df = pd.read_csv('e:\Disney Plus Content Data Analysis\disney_plus_titles.csv')
df.head()
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %%
df.shape
# Out:
# (1368, 12)

# %%
df.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        440
# cast            174
# country         175
# date_added        3
# release_year      0
# rating            2
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1368 non-null   object
#  1   type          1368 non-null   object
#  2   title         1368 non-null   object
#  3   director      928 non-null    object
#  4   cast          1194 non-null   object
#  5   country       1193 non-null   object
#  6   date_added    1365 non-null   object
#  7   release_year  1368 non-null   int64
#  8   rating        1366 non-null   object
#  9   duration      1368 non-null   object
#  10  listed_in     1368 non-null   object
#  11  description   1368 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 128.4+ KB

# %%
df.describe().round(2)
# Out:
#        release_year
# count       1368.00
# mean        2002.35
# std           22.13
# min         1928.00
# 25%         1998.00
# 50%         2011.00
# 75%         2018.00
# max         2021.00

# %%
df.type.value_counts()
# Out:
# type
# Movie      991
# TV Show    377
# Name: count, dtype: int64

# %%
df.type.value_counts().plot(kind='pie',explode=[0,0.05],autopct='%1.1f%%',ylabel='type');

# %%
df.type.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='type'>

# %%
# What type of content is the most?
sns.set_theme(style='whitegrid')
sns.countplot(x='type',data=df,orient='v',palette='hls')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.countplot(x='rating',data=df,orient='v',palette='husl')
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
df.head()
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %%
sns.displot(x='release_year',data=df,kde=True);

# %%
pd.crosstab(df.rating,df.type)
# Out:
# type      Movie  TV Show
# rating
# G           235        0
# PG          226        1
# PG-13        60        0
# TV-14        36       36
# TV-G        224       83
# TV-PG       165      110
# TV-Y          2       46
# TV-Y7        36       94
# TV-Y7-FV      6        6

# %%
sns.countplot(x='rating',data=df,hue='type',orient='v')
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
TV_Show = df[df['type']=='TV Show']
TV_Show
# Out:
#      show_id     type                                    title director  \
# 3         s4  TV Show                          Dog: Impossible      NaN
# 4         s5  TV Show           Spidey And His Amazing Friends      NaN
# 5         s6  TV Show                       Star Wars: Visions      NaN
# 13       s14  TV Show                          Life Below Zero      NaN
# 14       s15  TV Show  Miraculous: Tales Of Ladybug & Cat Noir      NaN
# ...      ...      ...                                      ...      ...
# 1344   s1345  TV Show                         X-Men: Evolution      NaN
# 1360   s1361  TV Show                                Smart Guy      NaN
# 1365   s1366  TV Show                     Disney Kirby Buckets      NaN
# 1366   s1367  TV Show                           Disney Mech-X4      NaN
# 1367   s1368  TV Show                       Imagination Movers      NaN
#
#                                                    cast  \
# ...

# %%
sns.countplot(y='duration',data=TV_Show,hue='type',palette='husl')
# Out:
# <Axes: xlabel='count', ylabel='duration'>

# %%
Movie = df[df['type']=='Movie']
Movie
# Out:
#      show_id   type                                     title  \
# 0         s1  Movie                             A Spark Story
# 1         s2  Movie                            Spooky Buddies
# 2         s3  Movie                    The Fault in Our Stars
# 6         s7  Movie               Confessions of a Shopaholic
# 7         s8  Movie                Descendants: Royal Wedding
# ...      ...    ...                                       ...
# 1359   s1360  Movie  Lady and the Tramp II: Scamp's Adventure
# 1361   s1362  Movie                  The Cat from Outer Space
# 1362   s1363  Movie                 The Great Mouse Detective
# 1363   s1364  Movie                    The Sword in the Stone
# 1364   s1365  Movie                           Those Calloways
#
#                                       director  \
# 0                   Jason Sterman, Leanne Dare
# 1                                 Robert Vince
# 2                                   Josh Boone
# ...

# %%
sns.countplot(x='rating',data=Movie,hue='type',palette='husl')
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
# top director
Movie.director.value_counts()[:20]
# Out:
# director
# Jack Hannah         17
# John Lasseter       16
# Paul Hoen           16
# Charles Nichols     12
# Robert Stevenson    12
# Bob Peterson        10
# Vincent McEveety    10
# Wilfred Jackson      9
# James Algar          9
# Kenny Ortega         9
# Norman Tokar         8
# Stuart Gillard       8
# Duwayne Dunham       8
# Jack Kinney          7
# Jon Turteltaub       6
# Clyde Geronimi       6
# Ben Sharpsteen       6
# Brad Bird            5
# Burt Gillett         5
# Michael Hegner       5
# Name: count, dtype: int64

# %%
# top director
Movie.director.value_counts()[:20].plot(kind='barh',color='salmon')
# Out:
# <Axes: ylabel='director'>

# %%
# top director
Movie.director.value_counts()[:10].plot(kind='bar',color='coral')
# Out:
# <Axes: xlabel='director'>

# %%
# top director
Movie.director.value_counts()[:5].plot(kind='bar',color='tan')
# Out:
# <Axes: xlabel='director'>

# %%
# old movies

Old_Movies = df[df['type']=='Movie'].sort_values('release_year',ascending=True).head(10)
Old_Movies
# Out:
#      show_id   type                     title                director  \
# 1146   s1147  Movie          Steamboat Willie  Walt Disney, Ub Iwerks
# 1104   s1105  Movie          Santa's Workshop         Wilfred Jackson
# 819     s820  Movie         Flowers and Trees            Burt Gillett
# 662     s663  Movie        Babes in the Woods            Burt Gillett
# 1345   s1346  Movie             Ye Olden Days            Bert Gillett
# 1288   s1289  Movie         Three Little Pigs            Burt Gillett
# 1243   s1244  Movie            The Pied Piper         Wilfred Jackson
# 848     s849  Movie  Grasshopper and the Ants         Wilfred Jackson
# 1282   s1283  Movie       The Wise Little Hen         Wilfred Jackson
# 1180   s1181  Movie          The Big Bad Wolf            Burt Gillett
#
#                                                    cast        country  \
# 1146                                        Walt Disney  United States
# ...

# %%
Old_Movies[['title','release_year']].head(10)
# Out:
#                          title  release_year
# 1146          Steamboat Willie          1928
# 1104          Santa's Workshop          1932
# 819          Flowers and Trees          1932
# 662         Babes in the Woods          1932
# 1345             Ye Olden Days          1933
# 1288         Three Little Pigs          1933
# 1243            The Pied Piper          1933
# 848   Grasshopper and the Ants          1934
# 1282       The Wise Little Hen          1934
# 1180          The Big Bad Wolf          1934

# %%
Country_Movies = df[df['type']=='Movie'].sort_values('country',ascending=True)
Country_Movies
# Out:
#      show_id   type                                   title  \
# 909     s910  Movie                            Jumping Ship
# 1221   s1222  Movie                     The Lion King 1 1/2
# 1093   s1094  Movie                               Rip Girls
# 208     s209  Movie               Okavango: River of Dreams
# 1274   s1275  Movie                    The Three Musketeers
# ...      ...    ...                                     ...
# 920     s921  Movie            Knick Knack Theatrical Short
# 962     s963  Movie  Marvel Studios: Expanding the Universe
# 1053   s1054  Movie        Phineas and Ferb: Mission Marvel
# 1062   s1063  Movie                     Planet of the Birds
# 1314   s1315  Movie                     Tree Climbing Lions
#
#                              director  \
# 909                     Michael Lange
# 1221                  Bradley Raymond
# 1093                     Joyce Chopra
# 208   Dereck Joubert, Beverly Joubert
# 1274                    Stephen Herek
# ...

# %%
Country_Movies_Count = Country_Movies.value_counts('country')[:10]
Country_Movies_Count
# Out:
# country
# United States                               752
# United States, Canada                        23
# United States, United Kingdom                18
# Canada, United States                        16
# United Kingdom, United States                13
# United Kingdom                               11
# United States, Australia                      7
# United States, United Kingdom, Australia      4
# United States, France                         4
# United States, United Kingdom, Canada         3
# Name: count, dtype: int64

# %%
Country_Movies_Count.plot(kind='bar',color='darkseagreen')
# Out:
# <Axes: xlabel='country'>

# %%
Country_Movies.value_counts('cast')[:10]
# Out:
# cast
# Winston Hibler                                                                                             10
# Larry the Cable Guy , Keith Ferguson                                                                        6
# Russell Boulter                                                                                             5
# Dan Nachtrab                                                                                                5
# Walt Disney                                                                                                 4
# Tom Kane, Anthony Daniels, Matt Sloan, Trevor Devall, Kirby Morrow, Sam Vincent                             3
# Vincent Martella, Ashley Tisdale, Thomas Brodie-Sangster, Caroline Rhea, Richard O'Brien, Dan Povenmire     3
# Ross Lynch, Maia Mitchell, Grace Phipps, Garrett Clayton, John DeLuca, Chrissie Fit                         2
# ...

# %%
Country_Movies_Sort = Country_Movies[Country_Movies['cast']=='Winston Hibler'].sort_values('title',ascending=True)
Country_Movies_Sort
# Out:
#      show_id   type                  title                         director  \
# 465     s466  Movie       In Beaver Valley                      James Algar
# 911     s912  Movie             Jungle Cat                      James Algar
# 468     s469  Movie     Nature's Half Acre                      James Algar
# 1045   s1046  Movie                  Perri  N. Paul Kenworthy, Ralph Wright
# 1111   s1112  Movie        Secrets of Life                      James Algar
# 1171   s1172  Movie       The African Lion                      James Algar
# 1227   s1228  Movie      The Living Desert                      James Algar
# 479     s480  Movie        The Olympic Elk                      James Algar
# 1280   s1281  Movie  The Vanishing Prairie                      James Algar
# 475     s476  Movie            Water Birds                   Ben Sharpsteen
#
#                 cast        country         date_added  release_year rating  \
# ...

# %%
sns.countplot(x='rating',data=Country_Movies_Sort,hue='cast',palette='flare')
# Out:
# <Axes: xlabel='rating', ylabel='count'>
